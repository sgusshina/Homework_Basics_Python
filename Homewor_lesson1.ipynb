# %%
import math
# Задание 1. 

phrase_1 = 'Насколько проще было бы писать программы, если бы не заказчики'
phrase_2 = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

print(len(phrase_1),len(phrase_2))
if len(phrase_1) > len(phrase_2):
  print('Фраза 1 длиннее фразы 2')
elif len(phrase_1) < len(phrase_2):
  print('Фраза 2 длиннее фразы 1')


# Задание 2.
year = 2022
if year % 4 == 0:
  print('Год високосный') 
else:
  print('Обычный год') 

# Задание 3
# Дополнительно учтено, сколько дней в каждом месяце

date = int(input(('Введите день')))
mounth = input('Введите месяц').capitalize()
if  1 <= date <= 31:
    if ( 22 <= date <= 31 and mounth == 'Декабрь') or  (date <= 20 and mounth == 'Январь'):
        print('Вы козерог')
    elif (21 <= date <= 31  and mounth == 'Январь') or  (date <= 20 and mounth == 'Февраль'):
        print('Вы водолей')
    elif (21 <= date <= 28 and mounth == 'Февраль') or  (date <= 20 and mounth == 'Март'):
        print('Вы рыбы')
    elif (21 <= date <= 31 and mounth == 'Март') or  (date <= 20 and mounth == 'Апрель'):
        print('Вы овен')
    elif (21 <= date <= 30 and mounth == 'Апрель') or  (date <= 20 and mounth == 'Май'):
        print('Вы телец')
    elif (21 <= date <= 31 and mounth == 'Май') or  (date <= 21 and mounth == 'Июнь'):
        print('Вы близнецы')
    elif (22 <= date <= 30 and mounth == 'Июнь') or  (date <= 22 and mounth == 'Июль'):
        print('Вы рак')
    elif (23 <= date <= 31 and mounth == 'Июль') or  (date <= 23 and mounth == 'Август'):
        print('Вы лев')
    elif (24 <= date <= 31 and mounth == 'Август') or  (date <= 23 and mounth == 'Сентябрь'):
        print('Вы дева')
    elif (24 <= date <= 30 and mounth == 'Сентябрь') or  (date <= 23 and mounth == 'Октябрь'):
        print('Вы весы')
    elif (24 <= date <= 31 and mounth == 'Октябрь') or  (date <= 22 and mounth == 'Ноябрь'):
        print('Вы скорпион')
    elif (23 <= date <= 30 and mounth == 'Ноябрь') or  (date <= 21 and mounth == 'Декабрь'):
        print('Вы стрелец')
    else:
        print('такого дня или месяца нет')
else:
    print('такого дня нет')

# Задание 4
width = int(input('Введите ширину товара в см'))
length = int(input('Введите длину товара в см'))
height = int(input('Введите высоту товара в см'))
if width <= 15 and length <=15 and height <=15:
    print('Коробка №1')
elif width >= 200 or length >= 200 or height >= 200:
    print ('Коробка для лыж')
elif 15 < width < 50 or 15 < length < 50 or 15 < height < 50:
    print('Коробка №2')
else:
    print('Коробка №3')

# Задание 5

number_ticket = 1243226
str_number = str(number_ticket)
list_number = list(str_number)
if len(str_number) == 6:
    for i in range(len(list_number)):
        sum_1 = int(list_number[0]) + int(list_number[1]) + int(list_number[2])
        sum_2 = int(list_number[3]) + int(list_number[4]) + int(list_number[5])

    if(sum_1 == sum_2): 
        print ('Счастливый билет')
    else:
        print ('Несчастливый билет')
else: 
   print ('В билете должно быть 6 цифр')  

# Задание 6

geometric_figure = input('Введите тип фигуры: треугольник, круг или прямоугольник').capitalize()
if geometric_figure == 'Круг':
   radius = int(input('Укажите радиус круга'))
   print('Площадь круга: ',radius**2*math.pi)
elif geometric_figure == 'Треугольник':
   side_1 = int(input('Укажите размер первой стороны треугольника'))
   side_2 = int(input('Укажите размер второй стороны треугольника'))
   side_3 = int(input('Укажите размер второй стороны треугольника'))
   perimetr = (side_1 + side_2 + side_3)/2
   print('Площадь треугольник: ',math.sqrt(perimetr)*(perimetr-side_1)*(perimetr-side_2)*(perimetr-side_3))
elif geometric_figure == 'Прямоугольник':
   side_1 = int(input('Укажите размер первой стороны прямоугольника'))
   side_2 = int(input('Укажите размер второй стороны прямоугольника'))
   print ('Площадь прямоугольника: ',side_1*side_2)
# Out:
# 62 61
# Фраза 1 длиннее фразы 2
# Обычный год
# Площадь прямоугольника:  20
